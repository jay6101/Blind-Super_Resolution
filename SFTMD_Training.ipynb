# %%
import imgaug as ia
import imgaug.augmenters as iaa
import torch
import torch.nn.functional as F
from torchvision import transforms
from torch.utils.data import Dataset
import cv2
import numpy as np
from sklearn.decomposition import PCA
from google.colab import drive
import math
from torchvision.utils import make_grid
import os, glob
import torch.nn as nn
from torch.nn import init
from torchvision.models import resnet18
from torch.utils.data import DataLoader
from PIL import Image
import time

# %%
torch.cuda.is_available()
# Out:
# True

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
default_augmentations = iaa.Sequential([
            iaa.Fliplr(0.5),
            iaa.Flipud(0.5), 
            iaa.Rot90([0, 1, 2, 3])])

default_transforms = transforms.ToTensor()

KERNEL_SIZE = 21

# %%
class KernelImagePair(Dataset):
    def __init__(self, imgs:list, 
                 kernel_pickle:str,
                 scale:int,
                 augmentations:object,
                 transforms:object,
                 seed=0,
                 patch_size=(256,256),
                 train=True, noise=False, interpolation="cubic", downsample_on_pipe=True):
        super(KernelImagePair, self).__init__()
        self._kernel_dict = torch.load(kernel_pickle)
        
        self.kernels = self._kernel_dict['kernels']  
        self.kernel_size = (KERNEL_SIZE, KERNEL_SIZE) 
        self.k_reduced = self._kernel_dict['kernels_compressed']
        self.stddevs = self._kernel_dict['sigmas']  

        self.pca = self._kernel_dict['pca']  
        
        self.imgs = imgs
        self.scale = scale
        self.augmentations = augmentations
        
        self.transforms = transforms
        self.seed = seed
        self.patch_size = patch_size
        self.train=train
        self.downsample_on_pipe = downsample_on_pipe
        
        if interpolation == "cubic":
            self.inter = cv2.INTER_CUBIC

        self.random = np.random.RandomState(seed)
        self.noise = None
        if noise:
            self.noise = iaa.AdditiveGaussianNoise(scale=(0.03*255, 0.1*255))
            
    def __getitem__(self, idx) -> dict:
        img = self.imgs[idx]
        img = cv2.imread(img, cv2.IMREAD_COLOR)
        
        if self.train:
            """
            Random Crop image Adding margin w.r.t kernel_size and patch_size
            """
            img_from, img_to = np.zeros(2, dtype=int), np.zeros(2, dtype=int)
            for i in range(2):
                img_from[i] = self.random.randint(0, img.shape[i] - (self.kernel_size[i] + 1 + self.patch_size[i]))
                img_to[i] = img_from[i] + self.kernel_size[i] + 1 + self.patch_size[i]
            img_patch = img[img_from[0]:img_to[0], img_from[1]:img_to[1]]
        else:
            img_patch = img
        
        if self.train and self.augmentations is not None:
            img_patch = self.augmentations.augment_image(img_patch)
            img = img_patch
        kernel_idx = self.random.randint(len(self.kernels))
        stddev = self.stddevs[kernel_idx]

        gaussian_kernel = self.kernels[kernel_idx].reshape(KERNEL_SIZE, KERNEL_SIZE).astype(np.float32)

        if self.downsample_on_pipe:
            img_blur = cv2.filter2D(img_patch, ddepth=-1, kernel=gaussian_kernel)
        else:
            img_blur = img_patch

        k_reduced = self.k_reduced[kernel_idx].astype(np.float32)

        if self.train:            
            half = self.kernel_size[0] // 2 + 1, self.kernel_size[1] // 2 + 1
            img_blur = img_blur[half[0] : -half[0], half[1]:-half[1]]
            img = img[half[0] : -half[0], half[1]:-half[1]]
            img_lr = cv2.resize(img_blur, 
                                (self.patch_size[0]//self.scale, self.patch_size[1]//self.scale), self.inter)
        if self.noise is not None:
                img_lr = self.noise.augment_image(img_lr)
        if self.downsample_on_pipe:
            img_lr = cv2.resize(img_blur, 
                    (img.shape[1]//self.scale, img.shape[0]//self.scale), self.inter)
        else:
            img_lr = img_blur
            img = cv2.imread(self.imgs[idx].replace("/lr/", "/hr/"))

        if self.transforms is not None:
            if self.train:
                if not img_lr.flags['C_CONTIGUOUS']:
                    img_lr = np.ascontiguousarray(img_lr)
                if not img.flags['C_CONTIGUOUS']:
                    img = np.ascontiguousarray(img)

            img_lr = self.transforms(img_lr)
            img = self.transforms(img)
        

        re_dict = dict(LR=img_lr,
                    HR=img,
                    k=gaussian_kernel,
                    k_reduced=k_reduced,
                    stddev=stddev,
                    )      
        return re_dict

    def __len__(self):
        return len(self.imgs)

# %%
def tensor2img(tensor, out_type=np.uint8, min_max=(0, 1)):
  
    tensor = tensor.squeeze().float().cpu().clamp_(*min_max)  
    tensor = (tensor - min_max[0]) / (min_max[1] - min_max[0])  
    n_dim = tensor.dim()
    if n_dim == 4:
        n_img = len(tensor)
        img_np = make_grid(tensor, padding=0, nrow=1, normalize=False).numpy()
        img_np = np.transpose(img_np[[2, 1, 0], :, :], (1, 2, 0))  

    if out_type == np.uint8:
        img_np = (img_np * 255.0).round()
    return img_np.astype(out_type)

# %%
def get_datasets(args):
    train_imgs = glob.glob("/content/drive/My Drive/CS663_project/DIV2K_train_HR/*.png", recursive=True)
    valid_imgs = glob.glob("/content/drive/My Drive/CS663_project/DIV2K_valid_HR/*.png", recursive=True)

    if args.augment == "default":
        augmentations = default_augmentations

    print(f"num of train {len(train_imgs)},  num of valid {len(valid_imgs)}.")

    train_dataset = KernelImagePair(imgs=train_imgs, 
                                    kernel_pickle=args.train_kernel, scale=args.scale, 
                                    augmentations=default_augmentations, transforms=default_transforms, 
                                    patch_size=(args.patch_size, args.patch_size),
                                    seed=args.seed, train=True, noise=args.use_noise, interpolation=args.inter)

    valid_dataset = KernelImagePair(imgs=valid_imgs, 
                                    kernel_pickle=args.train_kernel, scale=args.scale, 
                                    augmentations=default_augmentations, transforms=default_transforms, 
                                    patch_size=(args.patch_size, args.patch_size),
                                    seed=args.seed, train=True, interpolation=args.inter)

    rt_dict = dict(train_dataset=train_dataset,valid_dataset=valid_dataset)
    
    return rt_dict

# %%
class args():
    def __init__(self):
        self.scale = 4
        self.train_kernel = "/content/drive/My Drive/CS663_project/kernels_scale4dim10.pth"
        self.inter = "cubic"
        self.seed = None
        self.patch_size = 256
        self.augment = "default"
        self.use_noise = False
        self.batch_size=16
        self.num_step=1000
        self.validation_interval=500
        self.num_workers=4
        self.lr=0.00004
        self.lr_decay=0.4
        self.lr_min=1e-7
        self.lr_scheduler="cosine"
        self.optimizer="adam"
        self.loss="l2"
        self.metric="psnr"
        self.resume=False
        self.nf=64
        self.valid_rate=0.1
        self.kernel_dim=10
args = args()

# %%
class SFT_Layer(nn.Module):
    def __init__(self, nf=64, para=10):
        super(SFT_Layer, self).__init__()
        self.mul_conv1 = nn.Conv2d(para + nf, 32, kernel_size=3, stride=1, padding=1)
        self.mul_leaky = nn.LeakyReLU(0.2)
        self.mul_conv2 = nn.Conv2d(32, nf, kernel_size=3, stride=1, padding=1)

        self.add_conv1 = nn.Conv2d(para + nf, 32, kernel_size=3, stride=1, padding=1)
        self.add_leaky = nn.LeakyReLU(0.2)
        self.add_conv2 = nn.Conv2d(32, nf, kernel_size=3, stride=1, padding=1)

    def forward(self, feature_maps, para_maps):
        cat_input = torch.cat((feature_maps, para_maps), dim=1)
        mul = torch.sigmoid(self.mul_conv2(self.mul_leaky(self.mul_conv1(cat_input))))
        add = self.add_conv2(self.add_leaky(self.add_conv1(cat_input)))
        return feature_maps * mul + add

# %%
class SFT_Residual_Block(nn.Module):
    def __init__(self, nf=64, para=10):
        super(SFT_Residual_Block, self).__init__()
        self.sft1 = SFT_Layer(nf=nf, para=para)
        self.sft2 = SFT_Layer(nf=nf, para=para)
        self.conv1 = nn.Conv2d(in_channels=nf, out_channels=nf, kernel_size=3, stride=1, padding=1, bias=True)
        self.conv2 = nn.Conv2d(in_channels=nf, out_channels=nf, kernel_size=3, stride=1, padding=1, bias=True)

    def forward(self, feature_maps, para_maps):
        fea1 = F.relu(self.sft1(feature_maps, para_maps))
        fea2 = F.relu(self.sft2(self.conv1(fea1), para_maps))
        fea3 = self.conv2(fea2)
        return torch.add(feature_maps, fea3)

# %%
class SFTMD(nn.Module):
    def __init__(self, in_nc=3, out_nc=3, nf=64, nb=16, scale=4, input_para=10, min=0.0, max=1.0):
        super(SFTMD, self).__init__()
        self.min = min
        self.max = max
        self.para = input_para
        self.num_blocks = nb

        self.conv1 = nn.Conv2d(in_nc, nf, 3, stride=1, padding=1)
        self.relu_conv1 = nn.LeakyReLU(0.2)
        self.conv2 = nn.Conv2d(nf, nf, 3, stride=1, padding=1)
        self.relu_conv2 = nn.LeakyReLU(0.2)
        self.conv3 = nn.Conv2d(nf, nf, 3, stride=1, padding=1)

        for i in range(nb):
            self.add_module('SFT-residual' + str(i + 1), SFT_Residual_Block(nf=nf, para=input_para))

        self.sft = SFT_Layer(nf=nf, para=input_para)
        self.conv_mid = nn.Conv2d(in_channels=nf, out_channels=nf, kernel_size=3, stride=1, padding=1, bias=True)

        if scale == 4: #x4
            self.upscale = nn.Sequential(
                nn.Conv2d(in_channels=nf, out_channels=nf * scale, kernel_size=3, stride=1, padding=1, bias=True),
                nn.PixelShuffle(scale // 2),
                nn.LeakyReLU(0.2, inplace=True),
                nn.Conv2d(in_channels=nf, out_channels=nf * scale, kernel_size=3, stride=1, padding=1, bias=True),
                nn.PixelShuffle(scale // 2),
                nn.LeakyReLU(0.2, inplace=True),
            )

        self.conv_output = nn.Conv2d(in_channels=nf, out_channels=out_nc, kernel_size=9, stride=1, padding=4, bias=True)

    def forward(self, input_dict):
        input = input_dict['LR']
        ker_code = input_dict['k_reduced']
        
        B, C, H, W = input.size() 
        B_h, C_h = ker_code.size() 
        ker_code_exp = ker_code.view((B_h, C_h, 1, 1)).expand((B_h, C_h, H, W)) #kernel_map stretch

        fea_bef = self.conv3(self.relu_conv2(self.conv2(self.relu_conv1(self.conv1(input)))))
        fea_in = fea_bef
        for i in range(self.num_blocks):
            fea_in = self.__getattr__('SFT-residual' + str(i + 1))(fea_in, ker_code_exp)
        fea_mid = fea_in
        fea_add = torch.add(fea_mid, fea_bef)
        fea = self.upscale(self.conv_mid(self.sft(fea_add, ker_code_exp)))
        out = self.conv_output(fea)
        
        return out

# %%
def train_SFTMD(train_dl,valid_dl, model, epochs, optimizer, loss_func,batch_size,scheduler):
    os.makedirs( "/content/drive/My Drive/CS663_project/valid_results/", exist_ok=True)
    for t in range(0,epochs):  
      if t%10 == 0 and t!=0:
        path = "/content/drive/My Drive/CS663_project/SFTMD_temp{}.pth".format(t) 
        torch.save(net.state_dict(), path)
      if t%10 == 0:
        with torch.no_grad(): 
          bd = next(iter(valid_dl))
          for k,v in bd.items():
              bd[k] = v.cuda()                
          sr = net(bd)
          hr = bd['HR']
          lr = bd['LR']
          cat = torch.cat([sr, hr], dim=3)
          img = tensor2img(cat.detach())           
          lr_img = tensor2img(lr.detach())
          lr_img = cv2.resize(lr_img, (args.patch_size, args.batch_size * args.patch_size), interpolation=cv2.INTER_CUBIC)
          img = np.concatenate((lr_img, img), axis=1)         
          Image.fromarray(img).save("/content/drive/My Drive/CS663_project/valid_results/{}.png".format(t))
      #start =time.time()
      loss_calc = 0
      for batch in train_dl:
        input = batch
        for k,v in input.items():
          input[k] = v.cuda() 
        gt_hr = input['HR']
        sr = model(input)
        loss = loss_func(sr, gt_hr)
        loss_calc += loss
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
      scheduler.step(loss_calc)
      #end = time.time()
      #print(end-start)
      if t%3==0:
        print("loss after {} epochs".format(t),loss_calc)

# %%
datasets = get_datasets(args)
print(f"datasets are prepared.")
# Out:
# num of train 800,  num of valid 100.
# datasets are prepared.

# %%
train_dl = DataLoader(datasets['train_dataset'], batch_size=args.batch_size, shuffle=True, num_workers=args.num_workers, pin_memory=True)
valid_dl = DataLoader(datasets['valid_dataset'], batch_size=args.batch_size, shuffle=True, num_workers=args.num_workers, pin_memory=True)

# %%
net = SFTMD(input_para=args.kernel_dim, scale=args.scale, nf=args.nf).cuda()

# %%
loss = F.mse_loss

# %%
#metric

# %%
if args.optimizer == "adam":
    optimizer = torch.optim.Adam(filter(lambda x: x.requires_grad, net.parameters()), lr=args.lr)

# %%
#scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode="max", patience=5, factor=args.lr_decay)
scheduler = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(optimizer, T_0=40, eta_min=args.lr_min)

# %%
train_SFTMD(train_dl=train_dl,valid_dl=valid_dl,model= net,epochs=args.num_step, optimizer=optimizer, loss_func=loss,batch_size=args.batch_size,scheduler =scheduler)
# Out:
# loss after 0 epochs tensor(4.5461, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 3 epochs tensor(1.0047, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 6 epochs tensor(0.5023, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 9 epochs tensor(0.4548, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 12 epochs tensor(0.3919, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 15 epochs tensor(0.3622, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 18 epochs tensor(0.3526, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 21 epochs tensor(0.3097, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 24 epochs tensor(0.2563, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 27 epochs tensor(0.2450, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 30 epochs tensor(0.2546, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 33 epochs tensor(0.2341, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 36 epochs tensor(0.2406, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 39 epochs tensor(0.2216, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 42 epochs tensor(0.2182, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 45 epochs tensor(0.2228, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 48 epochs tensor(0.2136, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 51 epochs tensor(0.2088, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 54 epochs tensor(0.1984, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 57 epochs tensor(0.2041, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 60 epochs tensor(0.1973, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 63 epochs tensor(0.1956, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 66 epochs tensor(0.1968, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 69 epochs tensor(0.1956, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 72 epochs tensor(0.1884, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 75 epochs tensor(0.2008, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 78 epochs tensor(0.1827, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 81 epochs tensor(0.1982, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 84 epochs tensor(0.2003, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 87 epochs tensor(0.1845, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 90 epochs tensor(0.1760, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 93 epochs tensor(0.1784, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 96 epochs tensor(0.1877, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 99 epochs tensor(0.1869, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 102 epochs tensor(0.1890, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 105 epochs tensor(0.1777, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 108 epochs tensor(0.1874, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 111 epochs tensor(0.1831, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 114 epochs tensor(0.1889, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 117 epochs tensor(0.1885, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 120 epochs tensor(0.1836, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 123 epochs tensor(0.1862, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 126 epochs tensor(0.1836, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 129 epochs tensor(0.1922, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 132 epochs tensor(0.1824, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 135 epochs tensor(0.1705, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 138 epochs tensor(0.1786, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 141 epochs tensor(0.1820, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 144 epochs tensor(0.1790, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 147 epochs tensor(0.1763, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 150 epochs tensor(0.1750, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 153 epochs tensor(0.1827, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 156 epochs tensor(0.1769, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 159 epochs tensor(0.1738, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 162 epochs tensor(0.1753, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 165 epochs tensor(0.1762, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 168 epochs tensor(0.1676, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 171 epochs tensor(0.1760, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 174 epochs tensor(0.1688, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 177 epochs tensor(0.1711, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 180 epochs tensor(0.1668, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 183 epochs tensor(0.1611, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 186 epochs tensor(0.1638, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 189 epochs tensor(0.1593, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 192 epochs tensor(0.1729, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 195 epochs tensor(0.1674, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 198 epochs tensor(0.1744, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 201 epochs tensor(0.1672, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 204 epochs tensor(0.1718, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 207 epochs tensor(0.1656, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 210 epochs tensor(0.1767, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 213 epochs tensor(0.1727, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 216 epochs tensor(0.1638, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 219 epochs tensor(0.1674, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 222 epochs tensor(0.1639, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 225 epochs tensor(0.1685, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 228 epochs tensor(0.1665, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 231 epochs tensor(0.1727, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 234 epochs tensor(0.1757, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 237 epochs tensor(0.1610, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 240 epochs tensor(0.1714, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 243 epochs tensor(0.1647, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 246 epochs tensor(0.1637, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 249 epochs tensor(0.1626, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 252 epochs tensor(0.1748, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 255 epochs tensor(0.1677, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 258 epochs tensor(0.1660, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 261 epochs tensor(0.1651, device='cuda:0', grad_fn=<AddBackward0>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-92ad86d5dffb> in <module>()
# ----> 1 train_SFTMD(train_dl=train_dl,valid_dl=valid_dl,model= net,epochs=args.num_step, optimizer=optimizer, loss_func=loss,batch_size=args.batch_size,scheduler =scheduler)
#
# <ipython-input-13-e088f21f148f> in train_SFTMD(train_dl, valid_dl, model, epochs, optimizer, loss_func, batch_size, scheduler)
#      30         loss_calc += loss
#      31         optimizer.zero_grad()
# ---> 32         loss.backward()
#      33         optimizer.step()
#      34       scheduler.step(loss_calc)
#
# /usr/local/lib/python3.6/dist-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     219                 retain_graph=retain_graph,
#     220                 create_graph=create_graph)
# --> 221         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     222
#     223     def register_hook(self, hook):
#
# /usr/local/lib/python3.6/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#     130     Variable._execution_engine.run_backward(
#     131         tensors, grad_tensors_, retain_graph, create_graph,
# --> 132         allow_unreachable=True)  # allow_unreachable flag
#     133
#     134
#
# KeyboardInterrupt:

# %%
path = "/content/drive/My Drive/CS663_project/SFTMD_temp260.pth"
net.load_state_dict(torch.load(path))
# Out:
# <All keys matched successfully>

# %%
train_SFTMD(train_dl=train_dl,valid_dl=valid_dl,model= net,epochs=args.num_step, optimizer=optimizer, loss_func=loss,batch_size=args.batch_size,scheduler =scheduler)
# Out:
# loss after 261 epochs tensor(0.1708, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 264 epochs tensor(0.1668, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 267 epochs tensor(0.1597, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 270 epochs tensor(0.1645, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 273 epochs tensor(0.1547, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 276 epochs tensor(0.1604, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 279 epochs tensor(0.1729, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 282 epochs tensor(0.1625, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 285 epochs tensor(0.1679, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 288 epochs tensor(0.1655, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 291 epochs tensor(0.1629, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 294 epochs tensor(0.1646, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 297 epochs tensor(0.1619, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 300 epochs tensor(0.1572, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 303 epochs tensor(0.1567, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 306 epochs tensor(0.1589, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 309 epochs tensor(0.1697, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 312 epochs tensor(0.1562, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 315 epochs tensor(0.1621, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 318 epochs tensor(0.1581, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 321 epochs tensor(0.1599, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 324 epochs tensor(0.1564, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 327 epochs tensor(0.1671, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 330 epochs tensor(0.1636, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 333 epochs tensor(0.1611, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 336 epochs tensor(0.1606, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 339 epochs tensor(0.1683, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 342 epochs tensor(0.1645, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 345 epochs tensor(0.1601, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 348 epochs tensor(0.1692, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 351 epochs tensor(0.1604, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 354 epochs tensor(0.1672, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 357 epochs tensor(0.1621, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 360 epochs tensor(0.1622, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 363 epochs tensor(0.1569, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 366 epochs tensor(0.1663, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 369 epochs tensor(0.1643, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 372 epochs tensor(0.1614, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 375 epochs tensor(0.1609, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 378 epochs tensor(0.1568, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 381 epochs tensor(0.1514, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 384 epochs tensor(0.1555, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 387 epochs tensor(0.1549, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 390 epochs tensor(0.1498, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 393 epochs tensor(0.1562, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 396 epochs tensor(0.1622, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 399 epochs tensor(0.1525, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 402 epochs tensor(0.1471, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 405 epochs tensor(0.1598, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 408 epochs tensor(0.1602, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 411 epochs tensor(0.1599, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 414 epochs tensor(0.1540, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 417 epochs tensor(0.1561, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 420 epochs tensor(0.1569, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 423 epochs tensor(0.1646, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 426 epochs tensor(0.1539, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 429 epochs tensor(0.1562, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 432 epochs tensor(0.1709, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 435 epochs tensor(0.1486, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 438 epochs tensor(0.1583, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 441 epochs tensor(0.1613, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 444 epochs tensor(0.1551, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 447 epochs tensor(0.1580, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 450 epochs tensor(0.1580, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 453 epochs tensor(0.1579, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 456 epochs tensor(0.1542, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 459 epochs tensor(0.1598, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 462 epochs tensor(0.1453, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 465 epochs tensor(0.1523, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 468 epochs tensor(0.1540, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 471 epochs tensor(0.1581, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 474 epochs tensor(0.1498, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 477 epochs tensor(0.1517, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 480 epochs tensor(0.1544, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 483 epochs tensor(0.1432, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 486 epochs tensor(0.1567, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 489 epochs tensor(0.1565, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 492 epochs tensor(0.1608, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 495 epochs tensor(0.1526, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 498 epochs tensor(0.1534, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 501 epochs tensor(0.1535, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 504 epochs tensor(0.1546, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 507 epochs tensor(0.1591, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 510 epochs tensor(0.1465, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 513 epochs tensor(0.1572, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 516 epochs tensor(0.1537, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 519 epochs tensor(0.1599, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 522 epochs tensor(0.1642, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 525 epochs tensor(0.1553, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 528 epochs tensor(0.1570, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 531 epochs tensor(0.1499, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 534 epochs tensor(0.1539, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 537 epochs tensor(0.1534, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 540 epochs tensor(0.1604, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 543 epochs tensor(0.1561, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 546 epochs tensor(0.1605, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 549 epochs tensor(0.1612, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 552 epochs tensor(0.1595, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 555 epochs tensor(0.1481, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 558 epochs tensor(0.1556, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 561 epochs tensor(0.1523, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 564 epochs tensor(0.1548, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 567 epochs tensor(0.1578, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 570 epochs tensor(0.1472, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 573 epochs tensor(0.1470, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 576 epochs tensor(0.1566, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 579 epochs tensor(0.1518, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 582 epochs tensor(0.1475, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 585 epochs tensor(0.1501, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 588 epochs tensor(0.1562, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 591 epochs tensor(0.1577, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 594 epochs tensor(0.1563, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 597 epochs tensor(0.1559, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 600 epochs tensor(0.1560, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 603 epochs tensor(0.1527, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 606 epochs tensor(0.1479, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 609 epochs tensor(0.1501, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 612 epochs tensor(0.1455, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 615 epochs tensor(0.1577, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 618 epochs tensor(0.1677, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 621 epochs tensor(0.1425, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 624 epochs tensor(0.1518, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 627 epochs tensor(0.1464, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 630 epochs tensor(0.1570, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 633 epochs tensor(0.1522, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 636 epochs tensor(0.1486, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 639 epochs tensor(0.1514, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 642 epochs tensor(0.1458, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 645 epochs tensor(0.1538, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 648 epochs tensor(0.1491, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 651 epochs tensor(0.1556, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 654 epochs tensor(0.1564, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 657 epochs tensor(0.1462, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 660 epochs tensor(0.1566, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 663 epochs tensor(0.1462, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 666 epochs tensor(0.1609, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 669 epochs tensor(0.1520, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 672 epochs tensor(0.1532, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 675 epochs tensor(0.1513, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 678 epochs tensor(0.1533, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 681 epochs tensor(0.1606, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 684 epochs tensor(0.1512, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 687 epochs tensor(0.1535, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 690 epochs tensor(0.1538, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 693 epochs tensor(0.1522, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 696 epochs tensor(0.1498, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 699 epochs tensor(0.1525, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 702 epochs tensor(0.1457, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 705 epochs tensor(0.1521, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 708 epochs tensor(0.1500, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 711 epochs tensor(0.1470, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 714 epochs tensor(0.1519, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 717 epochs tensor(0.1521, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 720 epochs tensor(0.1528, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 723 epochs tensor(0.1398, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 726 epochs tensor(0.1565, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 729 epochs tensor(0.1549, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 732 epochs tensor(0.1502, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 735 epochs tensor(0.1433, device='cuda:0', grad_fn=<AddBackward0>)

# %%
path = "/content/drive/My Drive/CS663_project/SFTMD_temp730.pth"
net.load_state_dict(torch.load(path))
# Out:
# <All keys matched successfully>

# %%
train_SFTMD(train_dl=train_dl,valid_dl=valid_dl,model= net,epochs=args.num_step, optimizer=optimizer, loss_func=loss,batch_size=args.batch_size,scheduler =scheduler)
# Out:
# loss after 738 epochs tensor(0.1478, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 741 epochs tensor(0.1501, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 744 epochs tensor(0.1449, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 747 epochs tensor(0.1542, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 750 epochs tensor(0.1478, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 753 epochs tensor(0.1392, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 756 epochs tensor(0.1535, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 759 epochs tensor(0.1543, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 762 epochs tensor(0.1539, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 765 epochs tensor(0.1493, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 768 epochs tensor(0.1539, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 771 epochs tensor(0.1456, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 774 epochs tensor(0.1459, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 777 epochs tensor(0.1568, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 780 epochs tensor(0.1533, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 783 epochs tensor(0.1485, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 786 epochs tensor(0.1480, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 789 epochs tensor(0.1480, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 792 epochs tensor(0.1454, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 795 epochs tensor(0.1386, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 798 epochs tensor(0.1428, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 801 epochs tensor(0.1620, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 804 epochs tensor(0.1486, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 807 epochs tensor(0.1466, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 810 epochs tensor(0.1428, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 813 epochs tensor(0.1509, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 816 epochs tensor(0.1416, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 819 epochs tensor(0.1487, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 822 epochs tensor(0.1425, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 825 epochs tensor(0.1480, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 828 epochs tensor(0.1446, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 831 epochs tensor(0.1553, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 834 epochs tensor(0.1494, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 837 epochs tensor(0.1437, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 840 epochs tensor(0.1499, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 843 epochs tensor(0.1485, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 846 epochs tensor(0.1435, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 849 epochs tensor(0.1356, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 852 epochs tensor(0.1476, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 855 epochs tensor(0.1427, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 858 epochs tensor(0.1553, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 861 epochs tensor(0.1576, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 864 epochs tensor(0.1481, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 867 epochs tensor(0.1412, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 870 epochs tensor(0.1496, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 873 epochs tensor(0.1529, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 876 epochs tensor(0.1491, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 879 epochs tensor(0.1424, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 882 epochs tensor(0.1510, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 885 epochs tensor(0.1384, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 888 epochs tensor(0.1477, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 891 epochs tensor(0.1466, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 894 epochs tensor(0.1530, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 897 epochs tensor(0.1516, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 900 epochs tensor(0.1529, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 903 epochs tensor(0.1418, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 906 epochs tensor(0.1499, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 909 epochs tensor(0.1461, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 912 epochs tensor(0.1374, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 915 epochs tensor(0.1396, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 918 epochs tensor(0.1470, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 921 epochs tensor(0.1458, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 924 epochs tensor(0.1472, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 927 epochs tensor(0.1510, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 930 epochs tensor(0.1413, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 933 epochs tensor(0.1456, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 936 epochs tensor(0.1469, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 939 epochs tensor(0.1510, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 942 epochs tensor(0.1482, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 945 epochs tensor(0.1412, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 948 epochs tensor(0.1471, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 951 epochs tensor(0.1501, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 954 epochs tensor(0.1496, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 957 epochs tensor(0.1374, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 960 epochs tensor(0.1413, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 963 epochs tensor(0.1452, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 966 epochs tensor(0.1485, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 969 epochs tensor(0.1506, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 972 epochs tensor(0.1447, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 975 epochs tensor(0.1395, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 978 epochs tensor(0.1405, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 981 epochs tensor(0.1461, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 984 epochs tensor(0.1485, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 987 epochs tensor(0.1462, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 990 epochs tensor(0.1443, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 993 epochs tensor(0.1439, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 996 epochs tensor(0.1451, device='cuda:0', grad_fn=<AddBackward0>)
# loss after 999 epochs tensor(0.1517, device='cuda:0', grad_fn=<AddBackward0>)

# %%
train_SFTMD(train_dl=train_dl,valid_dl=valid_dl,model= net,epochs=args.num_step, optimizer=optimizer, loss_func=loss,batch_size=args.batch_size,scheduler =scheduler)
